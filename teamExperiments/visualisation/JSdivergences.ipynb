# %%
import os
os.chdir('/Users/thom/Personnel/Scolaire/MIA/snake2-beta-insa-main/data/teamExperiments')
from visualisation import *

# %%
JS_Array = []

for i in range(10):
    pathToDataset = 'createdSets/Task 1/synth/' + str(i+1) + '.npz'
    JS_Array.append(getJensenShannonDivergences(syntheticData_Task1, npzPrivateToDataframe(pathToDataset)))

# %%
myDF = pd.DataFrame(JS_Array)
myDF

plotDistributionByDay(myDF, palette=palette_Divergence, title="Jensen-Shannon Divergences distribution between Synthetic Task 1 and 10 false synthetics tasks")
