# %%
import os
os.chdir('/Users/thom/Personnel/Scolaire/MIA/snake2-beta-insa-main/data/teamExperiments')
from visualisation import *

# %%
plotDistributionByDay(dataframe=publicData_Tasks12, palette=palette_PublicDS, title = 'Distribution of the public dataset (Tasks 1 and 2)')

# %%
plotDistributionByDay(dataframe=publicData_Tasks34, palette=palette_PublicDS, title = 'Distribution of the public dataset (Tasks 3 and 4)')
