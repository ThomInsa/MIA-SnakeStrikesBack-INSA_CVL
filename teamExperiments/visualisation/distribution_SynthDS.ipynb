# %%
import os
os.chdir('/Users/thom/Personnel/Scolaire/MIA/snake2-beta-insa-main/data/teamExperiments')
from visualisation import *

# %%
plotDistributionByDay(dataframe=syntheticData_Task1, palette=palette_SyntheticDS, title ='Distribution of the synthetic dataset (Task 1)')

# %%
plotDistributionByDay(dataframe=syntheticData_Task2, palette=palette_SyntheticDS, title ='Distribution of the synthetic dataset (Task 2)')

# %%
plotDistributionByDay(dataframe=syntheticData_Task3, palette=palette_SyntheticDS, title ='Distribution of the synthetic dataset (Task 3)')

# %%
plotDistributionByDay(dataframe=syntheticData_Task4, palette=palette_SyntheticDS, title ='Distribution of the synthetic dataset (Task 4)')
